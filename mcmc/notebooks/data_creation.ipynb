# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
    
import sys 
sys.path.insert(0, '../src/')
sys.path.insert(0, '../../src/')


# import warnings; warnings.simplefilter('ignore')
import jsm_halopull
import jsm_SHMR
import jsm_mcmc

# %%
cores = np.array([4, 8, 12, 16])

key = np.array(["6p_allwalk", "6p_Ncorr_allwalk", "6p_fixed", "6p_Ncorr_fixed"])

time = np.array([6.4, 3.7, 2.9, 2.3])

# %%
plt.plot(cores, time, marker="o")
plt.axhline(time[0]/2, ls="--", color="grey", label="2 times faster")
plt.axhline(time[0]/4, ls="--", color="black", label="4 times faster!")


plt.title("Nwalker = 100, Nsteps=1000")
plt.ylabel("time (hours)")
plt.xlabel("N cores")
plt.legend()

plt.show()

# %% [markdown]
# ### simple fiducial model test

# %%
fid_theta = [10.5, 1.9, 0.2, 0, 0, 0]
index = 19

create = jsm_mcmc.mock_data(jsm_SHMR.general, fid_theta, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/model_runs/simple_fid/", read_red=True)
create.get_data_points(plot=True)
create.save_data()

# %% [markdown]
# ### complext fiducial model test

# %%
fid_theta = [10.5, 1.9, 0.2, -0.05, 0.01, 1.2]
index = 19

create = jsm_mcmc.mock_data(jsm_SHMR.general, fid_theta, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/model_runs/complex_fid/", read_red=True)
create.get_data_points(plot=True)
create.save_data()

# %% [markdown]
# ### creating the differnt Nsaga samples

# %%
fid_theta = [10.5, 1.9, 0.2, 0, 0, 0]

# %%
#10 hosts per sample

N10 = jsm_mcmc.SAGA_sample(Nsamp=10, SHMR=jsm_SHMR.general, truths=fid_theta, SAGA_ind=0,
                     savedir="../../mcmc/model_runs/Nsample/10/", read_red=True)

N10.get_data_points(plot=True)
N10.save_data()

# %%
#50 hosts per sample

N50 = jsm_mcmc.SAGA_sample(Nsamp=50, SHMR=jsm_SHMR.general, truths=fid_theta, SAGA_ind=0,
                     savedir="../../mcmc/model_runs/Nsample/50/", read_red=True)

N50.get_data_points(plot=True)
N50.save_data()

# %%
#500 hosts per sample

N500 = jsm_mcmc.SAGA_sample(Nsamp=500, SHMR=jsm_SHMR.general, truths=fid_theta, SAGA_ind=0,
                     savedir="../../mcmc/model_runs/Nsample/500/", read_red=True)

N500.get_data_points(plot=True)
N500.save_data()

# %%
#1000 hosts per sample

N1000 = jsm_mcmc.SAGA_sample(Nsamp=1000, SHMR=jsm_SHMR.general, truths=fid_theta, SAGA_ind=0,
                     savedir="../../mcmc/model_runs/Nsample/1000/", read_red=True)

N1000.get_data_points(plot=True)
N1000.save_data()
