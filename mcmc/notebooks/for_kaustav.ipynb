# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import warnings; warnings.simplefilter('ignore')
import sys
sys.path.insert(0, '/Users/jsmonzon/Research/SatGen/mcmc/src/')
import jsm_halopull
import jsm_SHMR
import jsm_mcmc
import jsm_stats
import jsm_models

# %%
test = np.load("../../../data/preliminary/test_evo/12_4_0/tree_0_evo.npz")

test["concentration"]
# Out:
# array([[  8.989758,   8.957011,   8.928306, ..., -99.      , -99.      ,
#         -99.      ],
#        [-99.      , -99.      , -99.      , ..., -99.      , -99.      ,
#         -99.      ],
#        [-99.      ,  26.722425,  26.722425, ..., -99.      , -99.      ,
#         -99.      ],
#        ...,
#        [-99.      , -99.      , -99.      , ..., -99.      , -99.      ,
#         -99.      ],
#        [-99.      , -99.      , -99.      , ..., -99.      , -99.      ,
#         -99.      ],
#        [-99.      , -99.      , -99.      , ..., -99.      , -99.      ,
#         -99.      ]], dtype=float32)

# %%
plt.plot(test["CosmicTime"], test["concentration"][9])
plt.ylim(0)
# Out:
# (0.0, 31.445474910736085)

# %%
plt.plot(test["CosmicTime"], np.log10(test["mass"][9]))

# %%
letso = jsm_halopull.MassMat("../../../data/MW-analog/meta_data_psi3/")

# %%
letso.write_to_FORTRAN()
# Out:
# writing out the subhalo data
