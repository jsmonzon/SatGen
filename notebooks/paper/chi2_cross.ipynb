# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import warnings; warnings.simplefilter('ignore')
import sys
sys.path.insert(0, '/Users/jsmonzon/Research/SatGen/mcmc/src/')
import jsm_halopull
import jsm_SHMR
import jsm_mcmc
import jsm_stats
import jsm_models
import matplotlib.patches as  mpatches

import seaborn as sns

# %%
fixed = [False, True, False, False, True, False]
fid_values = [2.0, 0.2]

s_0_0 = jsm_mcmc.Chain("../../mcmc/inference_tests/our_stats/s0_data/mock_0_0/chain.h5", fixed=fixed, Nburn=100, Nthin=15)
s_0_0_nadler = jsm_mcmc.Chain("../../mcmc/inference_tests/nadler_stats/s0_data/mock_0_0/chain.h5", fixed=fixed, Nburn=100, Nthin=15)

s_0_1 = jsm_mcmc.Chain("../../mcmc/inference_tests/our_stats/s0_data/mock_0_1/chain.h5", fixed=fixed, Nburn=100, Nthin=15)
s_0_1_nadler = jsm_mcmc.Chain("../../mcmc/inference_tests/nadler_stats/s0_data/mock_0_1/chain.h5", fixed=fixed, Nburn=100, Nthin=15)

s_0_2 = jsm_mcmc.Chain("../../mcmc/inference_tests/our_stats/s0_data/mock_0_2/chain.h5", fixed=fixed, Nburn=100, Nthin=15)
s_0_2_nadler = jsm_mcmc.Chain("../../mcmc/inference_tests/nadler_stats/s0_data/mock_0_2/chain.h5", fixed=fixed, Nburn=100, Nthin=15)


s_1_0 = jsm_mcmc.Chain("../../../data/big_files/mock_1_0/chain.h5", fixed=fixed, Nburn=15000, Nthin=25)
s_1_0_nadler = jsm_mcmc.Chain("../../mcmc/inference_tests/nadler_stats/s15_data/mock_1_0/chain.h5", fixed=fixed, Nburn=100, Nthin=15)

s_1_1 = jsm_mcmc.Chain("../../mcmc/inference_tests/our_stats/s15_data/mock_1_1/chain.h5", fixed=fixed, Nburn=100, Nthin=15)
s_1_1_nadler = jsm_mcmc.Chain("../../mcmc/inference_tests/nadler_stats/s15_data/mock_1_1/chain.h5", fixed=fixed, Nburn=100, Nthin=15)

s_1_2 = jsm_mcmc.Chain("../../mcmc/inference_tests/our_stats/s15_data/mock_1_2/chain.h5", fixed=fixed, Nburn=100, Nthin=15)
s_1_2_nadler = jsm_mcmc.Chain("../../mcmc/inference_tests/nadler_stats/s15_data/mock_1_2/chain.h5", fixed=fixed, Nburn=100, Nthin=15)


s_2_0_nadler = jsm_mcmc.Chain("../../mcmc/inference_tests/nadler_stats/s30_data/mock_2_0/chain.h5", fixed=fixed, Nburn=100, Nthin=15)

s_2_1 = jsm_mcmc.Chain("../../../data/big_files/mock_2_1/chain.h5", fixed=fixed, Nburn=15|000, Nthin=25)
s_2_1_nadler = jsm_mcmc.Chain("../../mcmc/inference_tests/nadler_stats/s30_data/mock_2_1/chain.h5", fixed=fixed, Nburn=100, Nthin=15)

s_2_2 = jsm_mcmc.Chain("../../mcmc/inference_tests/our_stats/s30_data/mock_2_2/chain.h5", fixed=fixed, Nburn=100, Nthin=15)
s_2_2_nadler = jsm_mcmc.Chain("../../mcmc/inference_tests/nadler_stats/s30_data/mock_2_2/chain.h5", fixed=fixed, Nburn=100, Nthin=15)

# %%
plt.style.use('../paper/paper.mplstyle')
double_textwidth = 7.0 #inches
single_textwidth = 3.5 #inches

# %%
# # Create a 4x3 subplot grid
# fig, axes = plt.subplots(2, 3, sharey="row", figsize=(12, double_textwidth))

# # Loop through each subplot and plot KDE of the corresponding parameter
# sns.kdeplot(s_0_0.chisq_thin, ax=axes[0,0], bw_adjust=1.2, fill=True, color="green")
# sns.kdeplot(s_0_1.chisq_thin, ax=axes[0,0], bw_adjust=1.2, fill=True, color="darkorange")
# sns.kdeplot(s_0_2.chisq_thin, ax=axes[0,0], bw_adjust=1.2, fill=True, color="red")
# axes[0,0].set_xlabel("$\chi^2_{jsm}$")
# axes[0,0].axvline(s_0_0.chisq_thin.min(), color="green", ls="--")
# axes[0,0].set_title("$s_0$ mock")

# sns.kdeplot(s_1_1.chisq_thin, ax=axes[0,1], bw_adjust=1.2, fill=True, color="darkorange")
# sns.kdeplot(s_1_2.chisq_thin, ax=axes[0,1], bw_adjust=1.2, fill=True, color="red")
# axes[0,1].set_xlabel("$\chi^2_{jsm}$")
# axes[0,1].axvline(s_1_1.chisq_thin.min(), color="darkorange", ls="--")
# axes[0,1].set_title("$s_{15}$ mock")

# sns.kdeplot(s_2_2.chisq_thin, ax=axes[0,2], bw_adjust=1.2, fill=True, color="red")
# axes[0,2].set_xlim(640, 670)
# axes[0,2].set_xlabel("$\chi^2_{jsm}$")
# axes[0,2].axvline(s_2_2.chisq_thin.min(), color="red", ls="--")
# axes[0,2].set_title("$s_{30}$ mock")

# sns.kdeplot(s_0_0_nadler.chisq_thin, ax=axes[1,0], bw_adjust=1.2, fill=True, color="green")
# sns.kdeplot(s_0_1_nadler.chisq_thin, ax=axes[1,0], bw_adjust=1.2, fill=True, color="darkorange")
# sns.kdeplot(s_0_2_nadler.chisq_thin, ax=axes[1,0], bw_adjust=1.2, fill=True, color="red")
# axes[1,0].set_xlim(85, 130)
# axes[1,0].set_xlabel("$\chi^2_{Nadler}$")
# axes[1,0].axvline(s_0_0_nadler.chisq_thin.min(), color="green", ls="--")

# sns.kdeplot(s_1_0_nadler.chisq_thin, ax=axes[1,1], bw_adjust=1.2, fill=True, color="green")
# sns.kdeplot(s_1_1_nadler.chisq_thin, ax=axes[1,1], bw_adjust=1.2, fill=True, color="darkorange")
# sns.kdeplot(s_1_2_nadler.chisq_thin, ax=axes[1,1], bw_adjust=1.2, fill=True, color="red")
# axes[1,1].set_xlim(100, 130)
# axes[1,1].set_xlabel("$\chi^2_{Nadler}$")
# axes[1,1].axvline(s_1_1_nadler.chisq_thin.min(), color="darkorange", ls="--")

# sns.kdeplot(s_2_0_nadler.chisq_thin, ax=axes[1,2], bw_adjust=1.2, fill=True, color="green")
# sns.kdeplot(s_2_1_nadler.chisq_thin, ax=axes[1,2], bw_adjust=1.2, fill=True, color="darkorange")
# sns.kdeplot(s_2_2_nadler.chisq_thin, ax=axes[1,2], bw_adjust=1.2, fill=True, color="red")
# axes[1,2].set_xlim(100, 140)
# axes[1,2].set_xlabel("$\chi^2_{Nadler}$")
# axes[1,2].axvline(s_2_2_nadler.chisq_thin.min(), color="red", ls="--")

# plt.tight_layout()
# #plt.savefig("../../figures/paper/chi_2_cross_sampling.pdf", bbox_inches="tight")
# plt.show()

# %%
# fig, axes = plt.subplots(6, 3, sharey='row', figsize=(double_textwidth, 8), gridspec_kw={'height_ratios': [1, 1.7, 1, 1.7, 1, 1.7]})

# sns.kdeplot(s_0_0.chisq_thin - s_0_0.chisq_thin.min(), ax=axes[0,0], bw_adjust=1.2, fill=True, color="steelblue")
# sns.kdeplot(s_0_0_nadler.chisq_thin - s_0_0_nadler.chisq_thin.min(), ax=axes[0,0], bw_adjust=1.2, fill=True, color="darkorange")

# sns.kdeplot(s_0_1.chisq_thin - s_0_0.chisq_thin.min(), ax=axes[0,1], bw_adjust=1.2, fill=True, color="steelblue")
# sns.kdeplot(s_0_1_nadler.chisq_thin - s_0_0_nadler.chisq_thin.min(), ax=axes[0,1], bw_adjust=1.2, fill=True, color="darkorange")

# sns.kdeplot(s_0_2.chisq_thin - s_0_0.chisq_thin.min(), ax=axes[0,2], bw_adjust=1.2, fill=True, color="steelblue")
# sns.kdeplot(s_0_2_nadler.chisq_thin - s_0_0_nadler.chisq_thin.min(), ax=axes[0,2], bw_adjust=1.2, fill=True, color="darkorange")

# sns.kdeplot(s_1_0.chisq_thin - s_1_1.chisq_thin.min(), ax=axes[2,0], bw_adjust=1.2, fill=True, color="steelblue")
# sns.kdeplot(s_1_0_nadler.chisq_thin - s_1_1_nadler.chisq_thin.min(), ax=axes[2,0], bw_adjust=1.2, fill=True, color="darkorange")

# sns.kdeplot(s_1_1.chisq_thin - s_1_1.chisq_thin.min(), ax=axes[2,1], bw_adjust=1.2, fill=True, color="steelblue")
# sns.kdeplot(s_1_1_nadler.chisq_thin - s_1_1_nadler.chisq_thin.min(), ax=axes[2,1], bw_adjust=1.2, fill=True, color="darkorange")

# sns.kdeplot(s_1_2.chisq_thin - s_1_1.chisq_thin.min(), ax=axes[2,2], bw_adjust=1.2, fill=True, color="steelblue")
# sns.kdeplot(s_1_2_nadler.chisq_thin - s_1_1_nadler.chisq_thin.min(), ax=axes[2,2], bw_adjust=1.2, fill=True, color="darkorange")

# #sns.kdeplot(s_2_0.chisq_thin - s_1_1.chisq_thin.min(), ax=axes[2,2], bw_adjust=1.2, fill=True, color="steelblue")
# sns.kdeplot(s_2_0_nadler.chisq_thin - s_2_2_nadler.chisq_thin.min(), ax=axes[4,0], bw_adjust=1.2, fill=True, color="darkorange")

# sns.kdeplot(s_2_1.chisq_thin - s_2_2.chisq_thin.min(), ax=axes[4,1], bw_adjust=1, fill=True, color="steelblue")
# sns.kdeplot(s_2_1_nadler.chisq_thin - s_2_2_nadler.chisq_thin.min(), ax=axes[4,1], bw_adjust=1.2, fill=True, color="darkorange")

# sns.kdeplot(s_2_2.chisq_thin - s_2_2.chisq_thin.min(), ax=axes[4,2], bw_adjust=1.2, fill=True, color="steelblue")
# sns.kdeplot(s_2_2_nadler.chisq_thin - s_2_2_nadler.chisq_thin.min(), ax=axes[4,2], bw_adjust=1.2, fill=True, color="darkorange")

# #s0_0
# sns.kdeplot(x=s_0_0_nadler.clean[:, 0], y=s_0_0_nadler.clean[:, 1], ax=axes[1,0], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="darkorange")
# sns.kdeplot(x=s_0_0.clean[:, 0], y=s_0_0.clean[:, 1], ax=axes[1,0], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="steelblue")
# #s0_1
# sns.kdeplot(x=s_0_1_nadler.clean[:, 0], y=s_0_1_nadler.clean[:, 1], ax=axes[1,1], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2.5, color="darkorange")
# sns.kdeplot(x=s_0_1.clean[:, 0], y=s_0_1.clean[:, 1], ax=axes[1,1], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="steelblue")
# #s0_2
# sns.kdeplot(x=s_0_2_nadler.clean[:, 0], y=s_0_2_nadler.clean[:, 1], ax=axes[1,2], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="darkorange")
# sns.kdeplot(x=s_0_2.clean[:, 0], y=s_0_2.clean[:, 1], ax=axes[1,2], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="steelblue")
# #s1_0
# sns.kdeplot(x=s_1_0_nadler.clean[:, 0], y=s_1_0_nadler.clean[:, 1], ax=axes[3,0], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="darkorange")
# sns.kdeplot(x=s_1_0.clean[:, 0], y=s_1_0.clean[:, 1], ax=axes[3,0], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2.5, color="steelblue")
# #s1_1
# sns.kdeplot(x=s_1_1_nadler.clean[:, 0], y=s_1_1_nadler.clean[:, 1], ax=axes[3,1], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="darkorange")
# sns.kdeplot(x=s_1_1.clean[:, 0], y=s_1_1.clean[:, 1], ax=axes[3,1], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="steelblue")
# #s1_2
# sns.kdeplot(x=s_1_2_nadler.clean[:, 0], y=s_1_2_nadler.clean[:, 1], ax=axes[3,2], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="darkorange")
# sns.kdeplot(x=s_1_2.clean[:, 0], y=s_1_2.clean[:, 1], ax=axes[3,2], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="steelblue")
# #s2_0
# sns.kdeplot(x=s_2_0_nadler.clean[:, 0], y=s_2_0_nadler.clean[:, 1], ax=axes[5,0], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2.5, color="darkorange")
# #s2_1
# sns.kdeplot(x=s_2_1_nadler.clean[:, 0], y=s_2_1_nadler.clean[:, 1], ax=axes[5,1], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="darkorange")
# sns.kdeplot(x=s_2_1.clean[:, 0], y=s_2_1.clean[:, 1], ax=axes[5,1], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=3, color="steelblue")
# #s2_2
# sns.kdeplot(x=s_2_2_nadler.clean[:, 0], y=s_2_2_nadler.clean[:, 1], ax=axes[5,2], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="darkorange")
# sns.kdeplot(x=s_2_2.clean[:, 0], y=s_2_2.clean[:, 1], ax=axes[5,2], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="steelblue")



# labels = [
#     "$S_{0} \\times S_{0}$",
#     "$S_{0} \\times S_{15}$",
#     "$S_{0} \\times S_{30}$",
#     "$S_{15} \\times S_{0}$",
#     "$S_{15} \\times S_{15}$",
#     "$S_{15} \\times S_{30}$",
#     "$S_{30} \\times S_{0}$",
#     "$S_{30} \\times S_{15}$",
#     "$S_{30} \\times S_{30}$"
# ]

# for index, ax in enumerate([axes[1,0], axes[1,1], axes[1,2], axes[3,0], axes[3,1], axes[3,2], axes[5,0], axes[5,1], axes[5,2]]):
#     ax.axhline(0.2, ls="--", color="grey")
#     ax.axvline(2.0, ls="--", color="grey")
#     ax.text(0.05, 0.8, labels[index], transform=ax.transAxes, bbox=dict(facecolor='white', alpha=1, edgecolor="k"))
#     ax.set_ylim(0, 1.12)
#     ax.set_xlim(1.7,2.3)
#     ax.set_xlabel("$\\alpha$")
#     ax.set_ylabel("$\\sigma$")

# for index, ax in enumerate([axes[0,0], axes[0,1], axes[0,2], axes[2,0], axes[2,1], axes[2,2], axes[4,0], axes[4,1], axes[4,2]]):
#     ax.axvline(0, ls="--", color="grey")
#     ax.set_xticks([0, 25, 50, 75])
#     ax.set_xlim(-5,100)
#     ax.set_xlabel("$\\chi^2 - \\chi^2_{\mathrm{min}}$")

# # handles = [mpatches.Patch(facecolor="orange", label="D23"),
# #            mpatches.Patch(facecolor="cornflowerblue", label="This Work")]
# # axes[2,0].legend(handles=handles, loc=4, framealpha=1)


# plt.tight_layout()
# plt.savefig("../../../paper_1/figures/feature_recovery/matrix_update.pdf", bbox_inches="tight")
# plt.show()
