# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import warnings; warnings.simplefilter('ignore')
import sys
sys.path.insert(0, '/Users/jsmonzon/Research/SatGen/mcmc/src/')
import jsm_halopull
import jsm_SHMR
import jsm_mcmc
import jsm_stats
import jsm_models

# %% [markdown]
# ## alpha permutations x 4

# %%
mock_1 = [10.5, 1.5, 0.2, 0, 0, 0] 
index = 99

create = jsm_models.MOCK_DATA(mock_1, "/Users/jsmonzon/Research/data/cross_host/lognorm_030_psi3/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/s30/alpha_permutations/mock_1/", index)
create.get_data_points(plot=True)
create.save_data()
# Out:
# selecting a single SAGA sample
# (100, 2499)

# %%
mock_2 = [10.5, 2.0, 0.2, 0, 0, 0] 
index = 99

create = jsm_models.MOCK_DATA(mock_2, "/Users/jsmonzon/Research/data/cross_host/lognorm_030_psi3/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/s30/alpha_permutations/mock_2/", index)
create.get_data_points(plot=True)
create.save_data()
# Out:
# selecting a single SAGA sample
# (100, 2499)

# %%
mock_3 = [10.5, 2.5, 0.2, 0, 0, 0] 
index = 99

create = jsm_models.MOCK_DATA(mock_3, "/Users/jsmonzon/Research/data/cross_host/lognorm_030_psi3/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/s30/alpha_permutations/mock_3/", index)
create.get_data_points(plot=True)
create.save_data()
# Out:
# selecting a single SAGA sample
# (100, 2499)

# %%
mock_4 = [10.5, 3.0, 0.2, 0, 0, 0] 
index = 99

create = jsm_models.MOCK_DATA(mock_4, "/Users/jsmonzon/Research/data/cross_host/lognorm_030_psi3/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/s30/alpha_permutations/mock_4/", index)
create.get_data_points(plot=True)
create.save_data()
# Out:
# selecting a single SAGA sample
# (100, 2499)

# %% [markdown]
# ## sigma permutations x3

# %%
# mock_1 = [10.5, 2.0, 0.2, 0, 0, 0] 
# index = 99

# create = jsm_models.MOCK_DATA(mock_1, "/Users/jsmonzon/Research/data/cross_host/lognorm_030_psi3/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/s30/sigma_permutations/mock_1/", index)
# create.get_data_points(plot=True)
# create.save_data()

# %%
mock_2 = [10.5, 2.0, 0.3, 0, 0, 0] 
index = 99

create = jsm_models.MOCK_DATA(mock_2, "/Users/jsmonzon/Research/data/cross_host/lognorm_030_psi3/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/s30/sigma_permutations/mock_2/", index)
create.get_data_points(plot=True)
create.save_data()
# Out:
# selecting a single SAGA sample
# (100, 2499)

# %%
mock_3 = [10.5, 2.0, 0.4, 0, 0, 0] 
index = 99

create = jsm_models.MOCK_DATA(mock_3, "/Users/jsmonzon/Research/data/cross_host/lognorm_030_psi3/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/s30/sigma_permutations/mock_3/", index)
create.get_data_points(plot=True)
create.save_data()
# Out:
# selecting a single SAGA sample
# (100, 2499)

# %%
mock_4 = [10.5, 2.0, 0.5, 0, 0, 0] 
index = 99

create = jsm_models.MOCK_DATA(mock_4, "/Users/jsmonzon/Research/data/cross_host/lognorm_030_psi3/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/s30/sigma_permutations/mock_4/", index)
create.get_data_points(plot=True)
create.save_data()
# Out:
# selecting a single SAGA sample
# (100, 2499)
