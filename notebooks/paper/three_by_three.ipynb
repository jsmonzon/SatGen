# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.image as mpimg
import matplotlib.patches as  mpatches
import warnings; warnings.simplefilter('ignore')
import sys
sys.path.insert(0, '/Users/jsmonzon/Research/SatGen/mcmc/src/')
import jsm_halopull
import jsm_SHMR
import jsm_mcmc
import jsm_stats
import jsm_models

# %%
plt.style.use('../../../paper_1/figures/paper.mplstyle')
double_textwidth = 7.1 #inches
single_textwidth = 3.5 #inches

# %%
fixed = [False, True, False, False, True, False]
fid_values = [2.0, 0.2]

s_0_0 = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/our_stats/s0_data/mock_0_0/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)
s_0_0_nadler = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/nadler_stats/s0_data/mock_0_0/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_0_1 = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/our_stats/s0_data/mock_0_1/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)
s_0_1_nadler = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/nadler_stats/s0_data/mock_0_1/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_0_2 = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/our_stats/s0_data/mock_0_2/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)
s_0_2_nadler = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/nadler_stats/s0_data/mock_0_2/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)



s_1_0_nadler = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/nadler_stats/s15_data/mock_1_0/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_1_1 = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/our_stats/s15_data/mock_1_1/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)
s_1_1_nadler = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/nadler_stats/s15_data/mock_1_1/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_1_2 = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/our_stats/s15_data/mock_1_2/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)
s_1_2_nadler = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/nadler_stats/s15_data/mock_1_2/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)



s_2_0_nadler = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/nadler_stats/s30_data/mock_2_0/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_2_1_nadler = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/nadler_stats/s30_data/mock_2_1/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_2_2 = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/our_stats/s30_data/mock_2_2/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)
s_2_2_nadler = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/nadler_stats/s30_data/mock_2_2/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

# %%
# Generate some random 2D data for demonstration
# Create a 3x3 grid of subplots
fig, axes = plt.subplots(3, 3, sharex=True, sharey=True, figsize=(double_textwidth, double_textwidth))

#s0_0
sns.kdeplot(x=s_0_0_nadler.clean[:, 0], y=s_0_0_nadler.clean[:, 1], ax=axes[0,0], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="darkorange")
sns.kdeplot(x=s_0_0.clean[:, 0], y=s_0_0.clean[:, 1], ax=axes[0,0], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="steelblue")

#s0_1
sns.kdeplot(x=s_0_1_nadler.clean[:, 0], y=s_0_1_nadler.clean[:, 1], ax=axes[0,1], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="darkorange")
sns.kdeplot(x=s_0_1.clean[:, 0], y=s_0_1.clean[:, 1], ax=axes[0,1], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="steelblue")
#s0_2
sns.kdeplot(x=s_0_2_nadler.clean[:, 0], y=s_0_2_nadler.clean[:, 1], ax=axes[0,2], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="darkorange")
sns.kdeplot(x=s_0_2.clean[:, 0], y=s_0_2.clean[:, 1], ax=axes[0,2], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="steelblue")

#s1_0
sns.kdeplot(x=s_1_0_nadler.clean[:, 0], y=s_1_0_nadler.clean[:, 1], ax=axes[1,0], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="darkorange")
#s1_1
sns.kdeplot(x=s_1_1_nadler.clean[:, 0], y=s_1_1_nadler.clean[:, 1], ax=axes[1,1], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="darkorange")
sns.kdeplot(x=s_1_1.clean[:, 0], y=s_1_1.clean[:, 1], ax=axes[1,1], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="steelblue")

#s1_2
sns.kdeplot(x=s_1_2_nadler.clean[:, 0], y=s_1_2_nadler.clean[:, 1], ax=axes[1,2], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="darkorange")
sns.kdeplot(x=s_1_2.clean[:, 0], y=s_1_2.clean[:, 1], ax=axes[1,2], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="steelblue")

#s2_0
sns.kdeplot(x=s_2_0_nadler.clean[:, 0], y=s_2_0_nadler.clean[:, 1], ax=axes[2,0], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="darkorange")
handles = [mpatches.Patch(facecolor="darkorange", label="D23"),
           mpatches.Patch(facecolor="steelblue", label="This Work")]
axes[2,0].legend(handles=handles, loc=4, framealpha=1)

#s2_1
sns.kdeplot(x=s_2_1_nadler.clean[:, 0], y=s_2_1_nadler.clean[:, 1], ax=axes[2,1], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="darkorange")
#s2_2
sns.kdeplot(x=s_2_2_nadler.clean[:, 0], y=s_2_2_nadler.clean[:, 1], ax=axes[2,2], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="darkorange")
sns.kdeplot(x=s_2_2.clean[:, 0], y=s_2_2.clean[:, 1], ax=axes[2,2], shade=False, shade_lowest=False, levels=[1-0.99, 1-0.95, 1-0.68], bw_adjust=2, color="steelblue")

labels = ["S0xS0", "S0xS15", "S0xS30",
          "S15xS0", "S15xS15", "S15xS30",
          "S30xS0", "S30xS15", "S30xS30"]

for index, ax in enumerate(axes.flatten()):
    ax.axhline(0.2, ls="--", color="grey")
    ax.axvline(2.0, ls="--", color="grey")
    ax.text(0.1, 0.85, labels[index], transform=ax.transAxes, bbox=dict(facecolor='white', alpha=1, edgecolor="k"))

axes[0,0].set_ylim(0, 1.12)
axes[0,0].set_ylabel("$\sigma$")
axes[1,0].set_ylabel("$\sigma$")
axes[2,0].set_ylabel("$\sigma$")

axes[2,0].set_xlabel("$\\alpha$")
axes[2,1].set_xlabel("$\\alpha$")
axes[2,2].set_xlabel("$\\alpha$")

# Adjust layout
plt.tight_layout()
plt.savefig("../../../paper_1/figures/updated/matrix.pdf", bbox_inches="tight")
plt.show()
