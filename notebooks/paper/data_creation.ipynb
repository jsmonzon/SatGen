# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import warnings; warnings.simplefilter('ignore')
import sys
sys.path.insert(0, '/Users/jsmonzon/Research/SatGen/mcmc/src/')
import jsm_halopull
import jsm_SHMR
import jsm_mcmc
import jsm_stats
import jsm_models

# %% [markdown]
# ## alpha permutations x 4

# %%
mock_0 = [10.5, 1.5, 0.2, 0, 0, 0] 
index = 55

create = jsm_models.MOCK_DATA(mock_0, "/Users/jsmonzon/Research/data/MW-analog/meta_data_psi4/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/s0/alpha_permutations/mock_0/", index)
create.get_data_points(plot=True)
create.save_data()
# Out:
# selecting a single SAGA sample
# (100, 1699)

# %%
mock_1 = [10.5, 2.0, 0.2, 0, 0, 0] 
index = 55

create = jsm_models.mock_data(mock_1, "/Users/jsmonzon/Research/data/MW-analog/meta_data_psi4/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/alpha_permutations/mock_1/", index)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_2 = [10.5, 2.5, 0.2, 0, 0, 0] #fiducial
index = 55

create = jsm_models.mock_data(mock_2, "/Users/jsmonzon/Research/data/MW-analog/meta_data_psi4/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/alpha_permutations/mock_2/", index)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_3 = [10.5, 3.0, 0.2, 0, 0, 0] 
index = 55

create = jsm_models.mock_data(mock_3, "/Users/jsmonzon/Research/data/MW-analog/meta_data_psi4/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/alpha_permutations/mock_3/", index)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_4 = [10.5, 3.5, 0.2, 0, 0, 0] 
index = 55

create = jsm_models.mock_data(mock_4, "/Users/jsmonzon/Research/data/MW-analog/meta_data_psi4/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/alpha_permutations/mock_4/", index)
create.get_data_points(plot=True)
create.save_data()

# %% [markdown]
# ## sigma permutations x3

# %%
# mock_1 = [10.5, 2.5, 0.2, 0, 0, 0] #fiducial
# index = 55

# create = jsm_models.mock_data(mock_1, "/Users/jsmonzon/Research/data/MW-analog/meta_data_psi4/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/alpha_permutations/mock_1/", index)
# create.get_data_points(plot=True)
# create.save_data()

# %%
mock_2 = [10.5, 2.5, 0.3, 0, 0, 0]
index = 55

create = jsm_models.mock_data(mock_2, "/Users/jsmonzon/Research/data/MW-analog/meta_data_psi4/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/sigma_permutations/mock_2/", index)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_3 = [10.5, 2.5, 0.4, 0, 0, 0]
index = 55

create = jsm_models.mock_data(mock_3, "/Users/jsmonzon/Research/data/MW-analog/meta_data_psi4/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/sigma_permutations/mock_3/", index)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_4 = [10.5, 2.5, 0.5, 0, 0, 0]
index = 55

create = jsm_models.mock_data(mock_4, "/Users/jsmonzon/Research/data/MW-analog/meta_data_psi4/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/sigma_permutations/mock_4/", index)
create.get_data_points(plot=True)
create.save_data()

# %% [markdown]
# ## beta permutations x3

# %%
mock_1 = [10.5, 2.5, 0.2, 0, 0.2, 0]
index = 55

create = jsm_models.mock_data(mock_1, "/Users/jsmonzon/Research/data/MW-analog/meta_data_psi4/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/beta_permutations/mock_1/", index)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_2 = [10.5, 2.5, 0.2, 0, 0.1, 0]
index = 55

create = jsm_models.mock_data(mock_2, "/Users/jsmonzon/Research/data/MW-analog/meta_data_psi4/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/beta_permutations/mock_2/", index)
create.get_data_points(plot=True)
create.save_data()

# %%
# mock_3 = [10.5, 2.5, 0.2, 0, 0.1, 0] # fiducial
# index = 55

# create = jsm_models.mock_data(mock_3, "/Users/jsmonzon/Research/data/MW-analog/meta_data_psi4/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/beta_permutations/mock_3/", index)
# create.get_data_points(plot=True)
# create.save_data()

# %%
mock_4 = [10.5, 2.5, 0.2, 0, -0.1, 0] # fiducial
index = 55

create = jsm_models.mock_data(mock_4, "/Users/jsmonzon/Research/data/MW-analog/meta_data_psi4/", "/Users/jsmonzon/Research/SatGen/mcmc/Feature_Recovery/beta_permutations/mock_4/", index)
create.get_data_points(plot=True)
create.save_data()

# %% [markdown]
# ## Fully general model

# %% [markdown]
# #### the L1 library

# %%
mock = [10.5, 2.3, 0.15, -0.1, 0.1, 0.6]
index = 22

create = jsm_models.MOCK_DATA(mock, "/Users/jsmonzon/Research/data/MW-analog/meta_data_psi4/", "/Users/jsmonzon/Research/SatGen/mcmc/General_Model/mock_L1/", index)
create.get_data_points(plot=True)
create.save_data()
# Out:
# selecting a single SAGA sample
# (100, 1699)

# %% [markdown]
# #### the L2 library

# %%
mock = [10.5, 2.3, 0.15, -0.1, 0.1, 0.6]
index = 22

create = jsm_models.MOCK_DATA(mock, "/Users/jsmonzon/Research/data/cross_host/lognorm_psi3/", "/Users/jsmonzon/Research/SatGen/mcmc/General_Model/mock_L2/", index)
create.get_data_points(plot=True)
create.save_data()
# Out:
# selecting a single SAGA sample
# (100, 1599)

# %%
test = np.load("../../../data/cross_host/lognorm_psi3/host_properties.npy")
L2 = test[2200:2300][:, 0]
L1 = np.zeros(100) + 12
binz = np.linspace(11.7, 12.3, 25)
#plt.hist(L1, bins=binz, edgecolor="white", color="firebrick", label="L1 library")
plt.hist(L2, bins=binz, edgecolor="white", color="cornflowerblue", label="L2 library")
plt.legend()
plt.show()

# %%
test = np.load("../../../data/cross_host/CLF_psi3/host_properties.npy")

plt.hist(test[2100:2200][:, 0], bins=15, edgecolor="white")
# Out:
# (array([ 3.,  6.,  7., 12.,  9., 14., 13., 11.,  7.,  5.,  4.,  4.,  1.,
#          2.,  2.]),
#  array([11.8896322 , 12.00334457, 12.11705695, 12.23076932, 12.34448169,
#         12.45819407, 12.57190644, 12.68561881, 12.79933119, 12.91304356,
#         13.02675593, 13.14046831, 13.25418068, 13.36789305, 13.48160543,
#         13.5953178 ]),
#  <BarContainer object of 15 artists>)

# %% [markdown]
# ### more 100x larger sample

# %%
mock = [10.5, 2.3, 0.15, -0.1, 0.1, 0.6]
index = [0,10]

create = jsm_models.MOCK_DATA(mock, "/Users/jsmonzon/Research/data/cross_host/lognorm_psi3/", "/Users/jsmonzon/Research/SatGen/mcmc/General_Model/mock_N_host/", index)
create.get_data_points(plot=True)
create.save_data()
# Out:
# selecting more than one SAGA sample
# (1000, 1599)

# %% [markdown]
# ## recreating the ELVES paper

# %%
mock = [10.5, 2.1, 0.06, 0.0, 0.0, 0.0]
index = 27.0

create = jsm_models.MOCK_DATA(mock, "/Users/jsmonzon/Research/data/cross_host/", "/Users/jsmonzon/Research/SatGen/mcmc/ELVES-test/1st_model/", SAGA_ind = index)
create.get_data_points(plot=True)
create.save_data()
# Out:
# selecting less than one SAGA sample
# (27, 24639)

# %%
mock = [10.5, 2.39, 0.02, -0.47, 0.0, 0.0]
index = 27.0

create = jsm_models.MOCK_DATA(mock, "/Users/jsmonzon/Research/data/cross_host/lognorm_psi3/", "/Users/jsmonzon/Research/SatGen/mcmc/ELVES-test/2nd_model/", SAGA_ind = index)
create.get_data_points(plot=True)
create.save_data()
# Out:
# selecting less than one SAGA sample
# (27, 1599)
