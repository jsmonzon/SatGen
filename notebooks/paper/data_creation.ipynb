# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import warnings; warnings.simplefilter('ignore')
import sys
sys.path.insert(0, '/Users/jsmonzon/Research/SatGen/mcmc/src/')
import jsm_halopull
import jsm_SHMR
import jsm_mcmc
import jsm_stats
import jsm_models

# %% [markdown]
# # Model A
# ## alpha permutations

# %%
mock_1 = [10.5, 2.0, 0.2, 0, 0, 0] #fiducial
index = 26

create = jsm_models.mock_data(jsm_SHMR.general, mock_1, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_A/alpha/mock_1/", read_red=True)
create.get_data_points(plot=True)
create.save_data()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       4 create = jsm_models.mock_data(jsm_SHMR.general, mock_1, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_A/alpha/mock_1/", read_red=True)
#       5 create.get_data_points(plot=True)
# ----> 6 create.save_data()
#
# File ~/Research/SatGen/mcmc/src/jsm_models.py:65, in mock_data.save_data(self)
#      64 def save_data(self):
# ---> 65     np.save(self.savedir+"mock_data.npy", np.array([self.lgMh_data, self.lgMs_data, self.zacc_data]))
#
# File <__array_function__ internals>:180, in save(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/subhalos/lib/python3.10/site-packages/numpy/lib/npyio.py:518, in save(file, arr, allow_pickle, fix_imports)
#     516     if not file.endswith('.npy'):
#     517         file = file + '.npy'
# ...

# %%
mock_2 = [10.5, 1.5, 0.2, 0, 0, 0]
index = 26

create = jsm_models.mock_data(jsm_SHMR.general, mock_2, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_A/alpha/mock_2/", read_red=True)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_3 = [10.5, 1.75, 0.2, 0, 0, 0]
index = 26

create = jsm_models.mock_data(jsm_SHMR.general, mock_3, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_A/alpha/mock_3/", read_red=True)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_4 = [10.5, 2.25, 0.2, 0, 0, 0]
index = 26

create = jsm_models.mock_data(jsm_SHMR.general, mock_4, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_A/alpha/mock_4/", read_red=True)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_5 = [10.5, 2.5, 0.2, 0, 0, 0]
index = 26

create = jsm_models.mock_data(jsm_SHMR.general, mock_5, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_A/alpha/mock_5/", read_red=True)
create.get_data_points(plot=True)
create.save_data()

# %% [markdown]
# ## sigma permutations

# %%
mock_1 = [10.5, 2.0, 0.1, 0, 0, 0] 
index = 26

create = jsm_models.mock_data(jsm_SHMR.general, mock_1, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_A/sigma/mock_1/", read_red=True)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_2 = [10.5, 2.0, 0.3, 0, 0, 0] 
index = 26

create = jsm_models.mock_data(jsm_SHMR.general, mock_2, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_A/sigma/mock_2/", read_red=True)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_3 = [10.5, 2.0, 0.4, 0, 0, 0] 
index = 26

create = jsm_models.mock_data(jsm_SHMR.general, mock_3, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_A/sigma/mock_3/", read_red=True)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_4 = [10.5, 2.0, 0.5, 0, 0, 0]
index = 26

create = jsm_models.mock_data(jsm_SHMR.general, mock_4, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_A/sigma/mock_4/", read_red=True)
create.get_data_points(plot=True)
create.save_data()

# %% [markdown]
# # Model B

# %%
mock_1 = [10.5, 2.0, 0.2, -0.05, 0, 0]
index = 26

create = jsm_models.mock_data(jsm_SHMR.general, mock_1, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_B/gamma/mock_1/", read_red=True)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_2 = [10.5, 2.0, 0.2, -0.02, 0, 0]
index = 26

create = jsm_models.mock_data(jsm_SHMR.general, mock_2, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_B/gamma/mock_2/", read_red=True)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_3 = [10.5, 2.0, 0.2, 0.02, 0, 0]
index = 26

create = jsm_models.mock_data(jsm_SHMR.general, mock_3, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_B/gamma/mock_3/", read_red=True)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_4 = [10.5, 2.0, 0.2, 0.05, 0, 0]
index = 26

create = jsm_models.mock_data(jsm_SHMR.general, mock_4, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_B/gamma/mock_4/", read_red=True)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_5 = [10.5, 2.0, 0.2, -0.08, 0, 0]
index = 26

create = jsm_models.mock_data(jsm_SHMR.general, mock_5, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_B/gamma/mock_5/", read_red=True)
create.get_data_points(plot=True)
create.save_data()

# %% [markdown]
# # Model C

# %%
mock_1 = [10.5, 2.0, 0.2, 0, 0.2, 0]
index = 26

create = jsm_models.mock_data(jsm_SHMR.general, mock_1, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_C/beta/mock_1/", read_red=True)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_2 = [10.5, 2.0, 0.2, 0, 0.1, 0]
index = 26

create = jsm_models.mock_data(jsm_SHMR.general, mock_2, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_C/beta/mock_2/", read_red=True)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_3 = [10.5, 2.0, 0.2, 0, -0.1, 0]
index = 26

create = jsm_models.mock_data(jsm_SHMR.general, mock_3, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_C/beta/mock_3/", read_red=True)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_4 = [10.5, 2.0, 0.2, 0, -0.2, 0]
index = 26

create = jsm_models.mock_data(jsm_SHMR.general, mock_4, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_C/beta/mock_4/", read_red=True)
create.get_data_points(plot=True)
create.save_data()

# %%
mock_5 = [10.5, 2.0, 0.2, 0, -0.25, 0]
index = 26

create = jsm_models.mock_data(jsm_SHMR.general, mock_5, index, "../../../data/MW-analog/meta_data_psi4/", "../../mcmc/paper_runs/model_C/beta/mock_5/", read_red=True)
create.get_data_points(plot=True)
create.save_data()
