# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import warnings; warnings.simplefilter('ignore')
import sys
sys.path.insert(0, '/Users/jsmonzon/Research/SatGen/mcmc/src/')
import jsm_halopull
import jsm_SHMR
import jsm_mcmc
import jsm_stats
import jsm_models

# %%
plt.style.use('../../../paper_1/figures/paper.mplstyle')
double_textwidth = 7.0 #inches
single_textwidth = 3.5 #inches

# %%
fixed = [False, True, False, False, True, False]

fid_values = [2.0, 0.2]

fiducial = jsm_mcmc.Chain("../../mcmc/simple_power_law/s15/alpha_permutations/mock_1/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

mock75 = jsm_mcmc.Chain("../../mcmc/fiducial/survey/mock_75/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

mock55 = jsm_mcmc.Chain("../../mcmc/fiducial/survey/mock_55/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

# %%
chain_labels = ["$\log M_{*}^{\mathrm{lim}}$ = 5.5 \n $\\alpha = $" + mock55.constraints[0] + "\n $\\sigma = $" + mock55.constraints[1],
                "$\log M_{*}^{\mathrm{lim}}$ = 6.5 \n $\\alpha = $" + fiducial.constraints[0] + "\n $\\sigma = $" + fiducial.constraints[1],
                "$\log M_{*}^{\mathrm{lim}}$ = 7.5 \n $\\alpha = $" + mock75.constraints[0] + "\n $\\sigma = $" + mock75.constraints[1]]


data = [mock55.clean, fiducial.clean, mock75.clean]
test = jsm_mcmc.MulitChain(data, chain_labels, fixed)
test.plot_posteriors(paper=True, filledPlots=True, nContourLevels=3, smoothingKernel=1.5, truths=fid_values, colorsOrder=["greens", "blues", "oranges"], paramRanges=[[1.9, 2.4], [0,1.1]], plotName="../../../paper_1/figures/feature_recovery/mag_limit.pdf")

# %%
mock300 = jsm_mcmc.Chain("../../mcmc/fiducial/survey/mock_300/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

mock500 = jsm_mcmc.Chain("../../mcmc/fiducial/survey/mock_500/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

mock1000 = jsm_mcmc.Chain("../../mcmc/fiducial/survey/mock_1000/chain.h5", fixed=fixed, Nstack=500, Nburn=1000, Nthin=15)

# %%
chain_labels = ["$N_{\mathrm{host}} = 500$ \n $\\alpha = $" + mock500.constraints[0] + "\n $\\sigma = $" + mock500.constraints[1],
                "$N_{\mathrm{host}} = 300$ \n $\\alpha = $" + mock300.constraints[0] + "\n $\\sigma = $" + mock300.constraints[1],
                "$N_{\mathrm{host}} = 100$ \n $\\alpha = $" + fiducial.constraints[0] + "\n $\\sigma = $" + fiducial.constraints[1]]


data = [mock500.clean, mock300.clean, fiducial.clean]
test = jsm_mcmc.MulitChain(data, chain_labels, fixed)
test.plot_posteriors(paper=True, filledPlots=True, nContourLevels=3, smoothingKernel=1.5, truths=fid_values, colorsOrder=["reds", "purples", "blues"], paramRanges=[[1.9, 2.4], [0,1.1]], plotName="../../../paper_1/figures/feature_recovery/Nhost.pdf")

# %%
chain_labels = ["$N_{\mathrm{host}} = 1000$ \n $\\alpha = $" + mock1000.constraints[0] + "\n $\\sigma = $" + mock1000.constraints[1],
                "$N_{\mathrm{host}} = 500$ \n $\\alpha = $" + mock500.constraints[0] + "\n $\\sigma = $" + mock500.constraints[1],
                "$N_{\mathrm{host}} = 300$ \n $\\alpha = $" + mock300.constraints[0] + "\n $\\sigma = $" + mock300.constraints[1],
                "$N_{\mathrm{host}} = 100$ \n $\\alpha = $" + fiducial.constraints[0] + "\n $\\sigma = $" + fiducial.constraints[1]]

data = [mock1000.clean, mock500.clean, mock300.clean, fiducial.clean]
test = jsm_mcmc.MulitChain(data, chain_labels, fixed)
test.plot_posteriors(filledPlots=True, nContourLevels=3, smoothingKernel=1.5, truths=fid_values, colorsOrder=["greens", "reds", "purples", "blues"], paramRanges=[[1.9, 2.4], [0,1.1]])#, plotName="../../../paper_1/figures/feature_recovery/Nhost.pdf")
