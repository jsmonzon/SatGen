# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import sys 
sys.path.insert(0, '../src/')
import jsm_mcmc
import jsm_SHMR

import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# selecting a paramtrization of the SHMR and reading in the data

# %%
fid_theta = [1.8, -0.2, 0.4, 10.1]
priors = [[-5, 5],[-3, 1],[0, 5], [9,12]]
params = ["a_1", "a_2", "a_3", "a_4"]
ndim = len(fid_theta)

# %%
massdir = "../../data/MW-analog/meta_data_psi3/"
datadir = "../../data/init_val/testing/"
data = jsm_mcmc.test_data(fid_theta, massdir+"jsm_MCMC.npy", datadir+"data.npy")
data.get_stats(min_mass=6.5)

# %% [markdown]
# defining the foward model(s). They don't include the SAGA index selected as "data"

# %%
def forward(theta):
    models = jsm_mcmc.models(theta, jsm_SHMR.anchor, data.lgMh_models)
    models.get_stats(min_mass=6.5)
    return models.stat.Pnsat, models.stat.Msmax, models.stat.ecdf_MsMax

# %% [markdown]
# defining the log likelyhood

# %%
def lnlike(theta):
    model_Pnsat, models_Msmax, _ = forward(theta)
    lnL_sat = jsm_mcmc.lnL_Pnsat(model_Pnsat, data.stat.satfreq)
    lnL_max = jsm_mcmc.lnL_KS(models_Msmax, data.stat.Msmax)
    return lnL_sat + lnL_max

def lnprior(theta):
    if priors[0][0] < theta[0] < priors[0][1] and priors[1][0] < theta[1] < priors[1][1] and priors[2][0] < theta[2] < priors[2][1]:
        lp = 0
    else:
        lp = -np.inf
    chi2_pr = ((theta[3] - 10.0) / 0.2) ** 2
    lnLPR = -chi2_pr / 2.0
    return lnLPR + lp

def lnprob(theta):
    lp = lnprior(theta)
    if not np.isfinite(lp):
        return -np.inf
    else:
        return lp + lnlike(theta)

# %% [markdown]
# intializing the run!

# %%
nwalk = 10
nsteps = 100
ndim = len(fid_theta)
#start_theta = [1.8, -1, 0.5, 10.1] # 1st
#start_theta = [1.8, -1, 0.5, 10.5] # 2nd
#start_theta = [1.8, -1, 1, 10.1] # 3rd
#start_theta = [1.8, -1, 0.1, 10.1] #4th
#start_theta = [1.8, -0.5, 0.1, 10.1] #5th

start_theta = [1.8, -0.2, 0.5, 10.1] #5.11
#start_theta = [1.8, -0.2, 0.1, 10.1] #5.1 works!
#start_theta = [1.8, -0.1, 0.1, 10.1] #5.5 works!
#start_theta = [1.8, 0, 0.1, 10.1] #6th works!

# %% [markdown]
# RUNNING!

# %%
mcmc_out = jsm_mcmc.RUN(start_theta, lnprob, nwalkers=nwalk, niter=nsteps, ndim=ndim, ncores=8, converge=False)
# Out:
# Run took 92.2 seconds

# %%
#run = jsm_mcmc.inspect_run(mcmc_out, fid_theta=data.fid_theta, labels=params, priors=priors, savedir=datadir, data=data, SHMR=jsm_SHMR.anchor, forward=forward, min_mass=6.5)

# %%
jsm_mcmc.inspect_run(mcmc_out, truths=data.truths, init_vals=start_theta, labels=params, priors=priors, savedir="old/test/", data=data, SHMR=jsm_SHMR.anchor, forward=forward, min_mass=6.5)
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/jsmonzon/Research/SatGen/notebooks/MCMC_minmass.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/Users/jsmonzon/Research/SatGen/notebooks/MCMC_minmass.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> jsm_mcmc.inspect_run(mcmc_out, truths=data.truths, init_vals=start_theta, labels=params, priors=priors, savedir="old/test/", data=data, SHMR=jsm_SHMR.anchor, forward=forward, min_mass=6.5)
#
# File ~/Research/SatGen/notebooks/../src/jsm_mcmc.py:163, in inspect_run.__init__(self, sampler, truths, init_vals, labels, priors, savedir, data, SHMR, forward, min_mass)
#     161 self.chain_plot()
#     162 self.corner_last_sample(zoom=False)
# --> 163 self.SHMR_plot(data, SHMR, self.min_mass)
#
# File ~/Research/SatGen/notebooks/../src/jsm_mcmc.py:350, in inspect_run.SHMR_plot(self, data, SHMR, show_scatter)
#     285         plt.savefig(self.savedir+"SHMR.png")
#     286         #plt.show()
#     287
#     288     # def corner_stack_samples(self, stack, zoom=False, plot=False):
#    (...)
#     346 #         axs[0,1].set_ylabel("a3")
#     347 #         axs[0,1].set_ylim(0,4)
# --> 350         axs[1,1].errorbar(xaxis, val_mat[:, 3, 0], yerr=[val_mat[:, 3, 1], val_mat[:, 3, 2]], fmt="o", color="black")
#     351         axs[1,1].axhline(10.1, ls=":")
#     352         axs[1,1].set_xlabel(xlabel)
#
# NameError: name 'axs' is not defined
