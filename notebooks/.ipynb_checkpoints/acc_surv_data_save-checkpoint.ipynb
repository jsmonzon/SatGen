# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt

import matplotlib.cm as cm
    
import sys  
sys.path.insert(0, '../src/')

from astropy.table import Table

from jsm_routines import data_save, SHMF
import os

# %%
data_save("../../data/dm_13_8_2900/evo/", "../../data/dm_13_8_2900/evo/","acc_surv", 1700, mlres=10**8)
# Out:
# number of realizations: 2921
# number of branches/halos: 1700
# 0

# %%
mass = np.load("../../data/dm_13_8_2900/evo/acc_surv_mass.npy")

red = np.load("../../data/dm_13_8_2900/evo/acc_surv_redshift.npy")

# %%
SHMF(mass, red, mass_min=-4)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# ../src/jsm_routines.py:212: RuntimeWarning: divide by zero encountered in log10
#   SHMF_quant = np.log10(np.percentile(I, [15, 50, 85], axis=0) / binsize)# this calculates the percentiles for each index
# ../src/jsm_routines.py:233: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(bincenters, np.log10(SHMF_ave/binsize), label="average", marker="o", color="black")
# ../src/jsm_routines.py:234: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(bincenters, np.log10((SHMF_ave+SHMF_std)/binsize), label="1 $\sigma$", marker=".", ls=":", color="grey")
# ../src/jsm_routines.py:235: RuntimeWarning: divide by zero encountered in log10
# ...
