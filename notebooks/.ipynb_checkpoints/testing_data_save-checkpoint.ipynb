# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt

import matplotlib.cm as cm
    
import sys  
sys.path.insert(0, '../src/')

from astropy.table import Table

from jsm_routines import data_save, SHMF
import os

# %%
data_save("../../data/dm_13_8_2900/", "../../data/dm_13_8_2900/","acc", 1700)
# Out:
# number of realizations: 2922
# number of branches/halos: 1700
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900

# %%
mass = np.load("../../data/dm_13_8_2900/acc_mass.npy")

red = np.load("../../data/dm_13_8_2900/acc_redshift.npy")

# %%
SHMF(mass, red)
# Out:
# ../src/jsm_routines.py:220: RuntimeWarning: divide by zero encountered in log10
#   SHMF_quant = np.log10(np.percentile(I, [15, 50, 85], axis=0) / binsize)# this calculates the percentiles for each index
# ../src/jsm_routines.py:241: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(bincenters, np.log10(SHMF_ave/binsize), label="average", marker="o", color="black")
# ../src/jsm_routines.py:242: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(bincenters, np.log10((SHMF_ave+SHMF_std)/binsize), label="1 $\sigma$", marker=".", ls=":", color="grey")
# ../src/jsm_routines.py:243: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(bincenters, np.log10((SHMF_ave-SHMF_std)/binsize), marker=".", ls=":", color="grey")
# ../src/jsm_routines.py:243: RuntimeWarning: invalid value encountered in log10
#   plt.plot(bincenters, np.log10((SHMF_ave-SHMF_std)/binsize), marker=".", ls=":", color="grey")
# (array([[0, 0, 0, ..., 0, 0, 0],
# ...

# %%
mass[0]

# %%
data_save("../../prelim/output_evolve/", "../../prelim/output_evolve/", "surv")
