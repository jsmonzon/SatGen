# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt

import matplotlib.cm as cm
    
import sys  
sys.path.insert(0, '../src/')

from astropy.table import Table

from jsm_routines import accretion_mass, surviving_mass, accretion_surviving_mass, SHMF
import os
import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# log10 (M*) = log10 (eM1)+ αlog10 (Mpeak) −α log10(M1)

# %%
def SHMR_Danieli(log_M_peak):
    
    e = -1.50
    
    a = 1.82
    
    return e*np.log10(10**(12.5)) + a*log_M_peak - a*np.log10(10**(12.5))

# %% [markdown]
# σ(Mpeak ) = σ0 + γ(log10 (Mpeak) − log( M1 ))

# %%
def SHMR_sigma_Danieli(log_M_peak):
    
    sigma_0 = 0.29
    
    gamma = -0.45
    
    return sigma_0 + gamma*((log_M_peak) - np.log10(10**12.5))

# %%
halo_masses = np.logspace(8,12.5,100)

stellar_masses = SHMR_Danieli(halo_masses)

sigma_stellar_masses = SHMR_sigma_Danieli(halo_masses)

# %%
stellar_masses
# Out:
# array([1.81999958e+08, 2.02081168e+08, 2.24378065e+08, 2.49135119e+08,
#        2.76623776e+08, 3.07145429e+08, 3.41034729e+08, 3.78663250e+08,
#        4.20443564e+08, 4.66833763e+08, 5.18342487e+08, 5.75534493e+08,
#        6.39036854e+08, 7.09545832e+08, 7.87834512e+08, 8.74761276e+08,
#        9.71279219e+08, 1.07844660e+09, 1.19743843e+09, 1.32955938e+09,
#        1.47625807e+09, 1.63914296e+09, 1.81999996e+09, 2.02081206e+09,
#        2.24378102e+09, 2.49135157e+09, 2.76623813e+09, 3.07145466e+09,
#        3.41034767e+09, 3.78663288e+09, 4.20443601e+09, 4.66833801e+09,
#        5.18342524e+09, 5.75534530e+09, 6.39036891e+09, 7.09545870e+09,
#        7.87834549e+09, 8.74761313e+09, 9.71279256e+09, 1.07844663e+10,
#        1.19743846e+10, 1.32955942e+10, 1.47625811e+10, 1.63914299e+10,
#        1.82000000e+10, 2.02081209e+10, 2.24378106e+10, 2.49135160e+10,
#        2.76623817e+10, 3.07145470e+10, 3.41034771e+10, 3.78663292e+10,
# ...

# %%
plt.figure(figsize=(10,10))

plt.plot(halo_masses, sigma_stellar_masses)
plt.xscale("log")

plt.xlabel("log M_peak", fontsize=20)
plt.ylabel("log M_star", fontsize=20)

plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(halo_masses, stellar_masses)
plt.yscale("log")
plt.xscale("log")

plt.xlabel("log M_peak", fontsize=20)
plt.ylabel("log M_star", fontsize=20)

plt.show()
