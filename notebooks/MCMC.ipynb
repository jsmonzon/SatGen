# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import sys 
sys.path.insert(0, '../src/')
import mcmc_aux
import SHMR

import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# selecting a mock survey from the 105 SAGA data sets

# %%
select = np.random.randint(0,105)
print("creating data from SAGA ID:", select)
# Out:
# creating data from SAGA ID: 98

# %% [markdown]
# selecting a paramtrization of the SHMR and reading in the data

# %%
fid_theta = [1.95, -0.3, 0.4]
priors = [[-5, 5],[-3, 1],[0, 5]]
params = ["a_1", "a_2", "a_3"]


data = mcmc_aux.mock_data(fid_theta, SHMR=SHMR.sigma, SAGA_ind=select, mfile="../../data/MCMC/SAGA_samples_10k.npy")
data.get_stats(min_mass=6.5)

# %% [markdown]
# defining the foward model(s). They don't include the SAGA index selected as "data"

# %%
def forward(theta):
    models = mcmc_aux.models(theta, SHMR.sigma, data.lgMh_models)
    models.get_stats(min_mass=6.5)
    return models.stat.Pnsat, models.stat.Msmax

# %% [markdown]
# defining the log likelyhood

# %%
def lnlike(theta):
    model_Pnsat, models_Msmax = forward(theta)
    lnL_sat = mcmc_aux.lnL_Pnsat(model_Pnsat, data.stat.satfreq)
    lnL_max = mcmc_aux.lnL_KS(models_Msmax, data.stat.Msmax)
    return lnL_sat + lnL_max

def lnprior(theta):
    a0, a1, a2 = theta
    if -5 < a0 < 5 and -3 < a1 < 1 and 0 < a2 < 5:
        return 0.0
    else:
        return -np.inf

def lnprob(theta):
    lp = lnprior(theta)
    if not np.isfinite(lp):
        return -np.inf
    else:
        return lp + lnlike(theta)

# %%
lnprob([1.8,-0.3,1])
# Out:
# -255.331802886492

# %% [markdown]
# intializing the run!

# %%
nwalk = 100
nsteps = 300
ndim = len(fid_theta)
start_theta = [1.4, -0.3, 1] # a somewhat random starting place

# %% [markdown]
# RUNNING!

# %%
mcmc_out = mcmc_aux.RUN(start_theta, lnprob, nwalkers=nwalk, niter=nsteps, ndim=ndim)
# Out:
# Run took 388.0 seconds

# %%
run = mcmc_aux.inspect_run(mcmc_out, fid_theta=data.fid_theta, labels=params, priors=priors)
run.chain_plot()

# %%
run.SHMR_plot(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/jsmonzon/Research/SatGen/notebooks/MCMC.ipynb Cell 17 line 1
# ----> <a href='vscode-notebook-cell:/Users/jsmonzon/Research/SatGen/notebooks/MCMC.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> run.SHMR_plot(data)
#
# File ~/Research/SatGen/notebooks/../src/mcmc_aux.py:175, in inspect_run.SHMR_plot(self, data)
#     173 SHMR_mat = np.zeros(shape=(self.last_samp.shape[0], self.halo_masses.shape[0]))
#     174 for i,val in enumerate(self.last_samp):
# --> 175     alpha_i, delta_i, sigma_i, gamma_i = val
#     176     lgMs = galhalo.SHMR_2D_g(self.halo_masses, alpha_i, delta_i, 0, gamma_i)
#     177     SHMR_mat[i] = lgMs
#
# ValueError: not enough values to unpack (expected 4, got 3)

# %%
run.corner_plot(burn=100)

# %%
run.stat_plot(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/jsmonzon/Research/SatGen/notebooks/MCMC.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell:/Users/jsmonzon/Research/SatGen/notebooks/MCMC.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> run.stat_plot(data)
#
# AttributeError: 'inspect_run' object has no attribute 'stat_plot'
