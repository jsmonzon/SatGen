# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import warnings; warnings.simplefilter('ignore')
import sys
sys.path.insert(0, '/Users/jsmonzon/Research/SatGen/mcmc/src/')
import jsm_halopull
import jsm_SHMR
import jsm_mcmc
import jsm_stats
import jsm_models

# %%
plt.style.use('../../../paper_1/figures/paper.mplstyle')
double_textwidth = 7.0 #inches
single_textwidth = 3.5 #inches

# %%
fixed = [False, True, False, False, True, False]
fid_values = [2.0, 0.2]

# %%
s_1_0 = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/cross/mock_1x0/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_1_1 = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/cross/mock_1x1/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_1_2 = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/cross/mock_1x2/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

# %%
binz = np.linspace(0, 18, 50)
plt.hist(s_1_0.chisq.flatten() - s_1_0.chisq.flatten().min(), bins=binz, edgecolor="white", density=True, alpha=0.4, color="orange")
plt.hist(s_1_1.chisq.flatten() - s_1_1.chisq.flatten().min(), bins=binz, edgecolor="white", density=True, alpha=0.4, color="blue")
plt.hist(s_1_2.chisq.flatten() - s_1_2.chisq.flatten().min(), bins=binz, edgecolor="white", density=True, alpha=0.4, color="green")
plt.show()

# %%
chain_labels = ["s_1_0 \n $\\alpha = $" + s_1_0.constraints[0] + "\n $\\sigma = $" + s_1_0.constraints[1],
                "s_1_1 \n $\\alpha = $" + s_1_1.constraints[0] + "\n $\\sigma = $" + s_1_1.constraints[1],
                "s_1_2 \n $\\alpha = $" + s_1_2.constraints[0] + "\n $\\sigma = $" + s_1_2.constraints[1]]

data_s0 = [s_1_0.clean, s_1_1.clean, s_1_2.clean]
test = jsm_mcmc.MulitChain(data_s0, chain_labels, fixed)
test.plot_posteriors(paper=True, filledPlots=True, nContourLevels=3, smoothingKernel=1.5, truths=fid_values, colorsOrder=["oranges", "blues", "greens"], paramRanges=[[1.9, 2.23], [0, 1.3]])

# %%
s_1_0 = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/cross_nadler/mock_1x0/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_1_1 = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/cross_nadler/mock_1x1/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_1_2 = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/cross_nadler/mock_1x2/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

# %%
binz = np.linspace(0, 18, 50)
plt.hist(s_1_0.chisq.flatten() - s_1_0.chisq.flatten().min(), bins=binz, edgecolor="white", density=True, alpha=0.4, color="orange")
plt.hist(s_1_1.chisq.flatten() - s_1_1.chisq.flatten().min(), bins=binz, edgecolor="white", density=True, alpha=0.4, color="blue")
plt.hist(s_1_2.chisq.flatten() - s_1_2.chisq.flatten().min(), bins=binz, edgecolor="white", density=True, alpha=0.4, color="green")
plt.show()

# %%
chain_labels = ["s_1_0 \n $\\alpha = $" + s_1_0.constraints[0] + "\n $\\sigma = $" + s_1_0.constraints[1],
                "s_1_1 \n $\\alpha = $" + s_1_1.constraints[0] + "\n $\\sigma = $" + s_1_1.constraints[1],
                "s_1_2 \n $\\alpha = $" + s_1_2.constraints[0] + "\n $\\sigma = $" + s_1_2.constraints[1]]

data_s0 = [s_1_0.clean, s_1_1.clean, s_1_2.clean]
test = jsm_mcmc.MulitChain(data_s0, chain_labels, fixed)
test.plot_posteriors(paper=True, filledPlots=True, nContourLevels=3, smoothingKernel=1.5, truths=fid_values, colorsOrder=["oranges", "blues", "greens"], paramRanges=[[1.9, 2.23], [0, 1.3]])

# %%
nadler_s15 = jsm_mcmc.Chain("../../mcmc/inference_tests/s15/mock_nadler/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_1_1 = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/cross_nadler/mock_1x1/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

fiducial_s15 = jsm_mcmc.Chain("../../mcmc/inference_tests/s15/mock_jsm/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

fiducial_s15_old = jsm_mcmc.Chain("../../mcmc/inference_tests/s15/mock_jsm_old/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

chain_labels = ["old limit", "new limit", "our stats", "old KS"]

# %%
data_s0 = [nadler_s15.clean, s_1_1.clean, fiducial_s15.clean, fiducial_s15_old.clean]
test = jsm_mcmc.MulitChain(data_s0, chain_labels, fixed)
test.plot_posteriors(paper=True, filledPlots=True, nContourLevels=3, smoothingKernel=1.5, truths=fid_values)

# %%
v1 = jsm_mcmc.Chain("../../mcmc/inference_tests/fid_stats/s15_data/mock_1_1/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

v2 = jsm_mcmc.Chain("../../mcmc/inference_tests/cross/mock_1x1/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

# %%
chain_labels = ["v1", "v2"]
data_s0 = [v1.clean, v2.clean]
test = jsm_mcmc.MulitChain(data_s0, chain_labels, fixed)
test.plot_posteriors(paper=True, filledPlots=True, nContourLevels=3, smoothingKernel=1.5, truths=fid_values)
