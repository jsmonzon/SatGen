# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import warnings; warnings.simplefilter('ignore')
import sys
sys.path.insert(0, '/Users/jsmonzon/Research/SatGen/mcmc/src/')
import jsm_halopull
import jsm_SHMR
import jsm_mcmc
import jsm_stats
import jsm_models

# %%
plt.style.use('../../../paper_1/figures/paper.mplstyle')
double_textwidth = 7.0 #inches
single_textwidth = 3.5 #inches

# %%
fixed = [False, True, False, False, True, False]
fid_values = [2.0, 0.2]

# %%
s_0_0 = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/our_stats/s0_data/mock_0_0/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_0_0_nadler = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/nadler_stats/s0_data/mock_0_0/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

binz = np.linspace(0, 18, 50)
plt.hist(s_0_0.chisq.flatten() - s_0_0.chisq.flatten().min(), bins=binz, edgecolor="white", density=True, alpha=0.4, color="cornflowerblue")
plt.hist(s_0_0_nadler.chisq.flatten() - s_0_0_nadler.chisq.flatten().min(), bins=binz, edgecolor="white", density=True, alpha=0.4, color="darkorange")
plt.xlabel("$\Delta \\chi^2$")
plt.ylabel("PDF")
plt.show()

chain_labels = ["s_0_0 \n $\\alpha = $" + s_0_0.constraints[0] + "\n $\\sigma = $" + s_0_0.constraints[1],
                "s_0_0 \n $\\alpha = $" + s_0_0_nadler.constraints[0] + "\n $\\sigma = $" + s_0_0_nadler.constraints[1]]

data_s0 = [s_0_0.clean, s_0_0_nadler.clean]
test = jsm_mcmc.MulitChain(data_s0, chain_labels, fixed)
test.plot_posteriors(paper=True, filledPlots=True, nContourLevels=2, smoothingKernel=1.5, truths=fid_values, colorsOrder=["blues", "oranges"], truthColors="k", truthLabels="made with S0 data", paramRanges=[[1.9, 2.3], [0, 0.8]])

# %%
s_0_1 = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/our_stats/s0_data/mock_0_1/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_0_1_nadler = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/nadler_stats/s0_data/mock_0_1/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

binz = np.linspace(0, 18, 50)
plt.hist(s_0_1.chisq.flatten() - s_0_1.chisq.flatten().min(), bins=binz, edgecolor="white", density=True, alpha=0.4, color="cornflowerblue")
plt.hist(s_0_1_nadler.chisq.flatten() - s_0_1_nadler.chisq.flatten().min(), bins=binz, edgecolor="white", density=True, alpha=0.4, color="darkorange")
plt.xlabel("$\Delta \\chi^2$")
plt.ylabel("PDF")
plt.show()

chain_labels = ["s_0_1 \n $\\alpha = $" + s_0_1.constraints[0] + "\n $\\sigma = $" + s_0_1.constraints[1],
                "s_0_1 \n $\\alpha = $" + s_0_1_nadler.constraints[0] + "\n $\\sigma = $" + s_0_1_nadler.constraints[1]]

data_s0 = [s_0_1.clean, s_0_1_nadler.clean]
test = jsm_mcmc.MulitChain(data_s0, chain_labels, fixed)
test.plot_posteriors(paper=True, filledPlots=True, nContourLevels=2, smoothingKernel=1.5, truths=fid_values, colorsOrder=["blues", "oranges"], truthColors="k", truthLabels="made with S0 data", paramRanges=[[1.9, 2.3], [0, 0.8]])

# %%
s_0_2 = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/our_stats/s0_data/mock_0_2/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_0_2_nadler = jsm_mcmc.Chain("../../../data/remote_pull/inference_tests/nadler_stats/s0_data/mock_0_2/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

binz = np.linspace(0, 18, 50)
plt.hist(s_0_2.chisq.flatten() - s_0_2.chisq.flatten().min(), bins=binz, edgecolor="white", density=True, alpha=0.4, color="cornflowerblue")
plt.hist(s_0_2_nadler.chisq.flatten() - s_0_2_nadler.chisq.flatten().min(), bins=binz, edgecolor="white", density=True, alpha=0.4, color="darkorange")
plt.xlabel("$\Delta \\chi^2$")
plt.ylabel("PDF")
plt.show()

chain_labels = ["s_0_2 \n $\\alpha = $" + s_0_2.constraints[0] + "\n $\\sigma = $" + s_0_2.constraints[1],
                "s_0_2 \n $\\alpha = $" + s_0_2_nadler.constraints[0] + "\n $\\sigma = $" + s_0_2_nadler.constraints[1]]

data_s0 = [s_0_2.clean, s_0_2_nadler.clean]
test = jsm_mcmc.MulitChain(data_s0, chain_labels, fixed)
test.plot_posteriors(paper=True, filledPlots=True, nContourLevels=2, smoothingKernel=1.5, truths=fid_values, colorsOrder=["blues", "oranges"], truthColors="k", truthLabels="made with S0 data", paramRanges=[[1.9, 2.3], [0, 0.8]])
