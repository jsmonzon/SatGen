# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import warnings; warnings.simplefilter('ignore')
import sys
sys.path.insert(0, '/Users/jsmonzon/Research/SatGen/mcmc/src/')
import jsm_halopull
import jsm_SHMR
import jsm_mcmc
import jsm_stats
import jsm_models

# %%
plt.style.use('../../../paper_1/figures/paper.mplstyle')
double_textwidth = 7.0 #inches
single_textwidth = 3.5 #inches

# %%
from chainconsumer import Chain, ChainConsumer, make_sample, Truth
import pandas as pd

df = make_sample()
c = ChainConsumer()
c.add_chain(Chain(samples=df, name="An Example Contour"))
fig = c.plotter.plot()

# %%
fixed = [False, True, False, False, True, False]
fid_values = [2.0, 0.2]

# %%
fiducial_s0 = jsm_mcmc.Chain("../../mcmc/inference_tests/s0/mock_jsm/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

df_fid_s0 = pd.DataFrame(fiducial_s0.clean, columns=["$\\alpha$", "$\\sigma$"])
df_fid_s0["log_posterior"] = np.zeros(shape=df_fid_s0.shape[0])

nadler_s0 = jsm_mcmc.Chain("../../mcmc/inference_tests/s0/mock_nadler/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

df_nad_s0 = pd.DataFrame(nadler_s0.clean, columns=["$\\alpha$", "$\\sigma$"])
df_nad_s0["log_posterior"] = np.zeros(shape=df_nad_s0.shape[0])

# %%
c = ChainConsumer()
c.add_chain(Chain(samples=df_fid_s0, name="our stats", show_contour_labels=True, kde=1.5, color="red"))
c.add_chain(Chain(samples=df_nad_s0, name="nadler's stats", show_contour_labels=True, kde=1.5))
c.add_truth(Truth(location={"$\\alpha$": 2.0, "$\\sigma$": 0.2}))
fig = c.plotter.plot()

# %%
fiducial_s15 = jsm_mcmc.Chain("../../mcmc/inference_tests/s15/mock_jsm/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

df_fid_s15 = pd.DataFrame(fiducial_s15.clean, columns=["$\\alpha$", "$\\sigma$"])
df_fid_s15["log_posterior"] = np.zeros(shape=df_fid_s15.shape[0])

nadler_s15 = jsm_mcmc.Chain("../../mcmc/inference_tests/s15/mock_nadler/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

df_nad_s15 = pd.DataFrame(nadler_s15.clean, columns=["$\\alpha$", "$\\sigma$"])
df_nad_s15["log_posterior"] = np.zeros(shape=df_nad_s15.shape[0])

# %%
c = ChainConsumer()
c.add_chain(Chain(samples=df_fid_s15, name="our stats", show_contour_labels=True, kde=1.5, color="red"))
c.add_chain(Chain(samples=df_nad_s15, name="nadler's stats", show_contour_labels=True, kde=1.5))
c.add_truth(Truth(location={"$\\alpha$": 2.0, "$\\sigma$": 0.2}))
fig = c.plotter.plot()
