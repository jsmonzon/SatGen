# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import warnings; warnings.simplefilter('ignore')
import sys
sys.path.insert(0, '/Users/jsmonzon/Research/SatGen/mcmc/src/')
import jsm_halopull
import jsm_SHMR
import jsm_mcmc
import jsm_stats
import jsm_models

# %%
plt.style.use('../../../paper_1/figures/paper.mplstyle')
double_textwidth = 7.0 #inches
single_textwidth = 3.5 #inches

# %%
fixed = [False, True, False, False, True, False]
fid_values = [2.0, 0.2]

# %%
fiducial_s0 = jsm_mcmc.Chain("../../mcmc/inference_tests/s0/mock_jsm/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=30)

nadler_s0 = jsm_mcmc.Chain("../../mcmc/inference_tests/s0/mock_nadler/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

# %%
chain_labels = ["Danieli's method \n $\\alpha = $" + nadler_s0.constraints[0] + "\n $\\sigma = $" + nadler_s0.constraints[1],
                "Our method \n $\\alpha = $" + fiducial_s0.constraints[0] + "\n $\\sigma = $" + fiducial_s0.constraints[1]]

data_s0 = [nadler_s0.clean, fiducial_s0.clean]
test = jsm_mcmc.MulitChain(data_s0, chain_labels, fixed)
test.plot_posteriors(paper=True, filledPlots=True, nContourLevels=3, smoothingKernel=1.5, truths=fid_values, colorsOrder=["oranges", "blues"], paramRanges=[[1.9, 2.3], [0, 1]])

# %%
fiducial_s15 = jsm_mcmc.Chain("../../mcmc/inference_tests/s15/mock_jsm/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=30)

nadler_s15 = jsm_mcmc.Chain("../../mcmc/inference_tests/s15/mock_nadler/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

# %%
chain_labels = ["Danieli's method \n $\\alpha = $" + nadler_s15.constraints[0] + "\n $\\sigma = $" + nadler_s15.constraints[1],
                "Our method \n $\\alpha = $" + fiducial_s15.constraints[0] + "\n $\\sigma = $" + fiducial_s15.constraints[1]]

data_s15 = [nadler_s15.clean, fiducial_s15.clean]
test = jsm_mcmc.MulitChain(data_s15, chain_labels, fixed)
test.plot_posteriors(paper=True, filledPlots=True, nContourLevels=3, smoothingKernel=1.5, truths=fid_values, colorsOrder=["oranges", "blues"], paramRanges=[[1.9, 2.3], [0, 1]])

# %%
fiducial_s30 = jsm_mcmc.Chain("../../mcmc/inference_tests/s30/mock_jsm/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=30)

nadler_s30 = jsm_mcmc.Chain("../../mcmc/inference_tests/s30/mock_nadler/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

# %%
chain_labels = ["Danieli's method \n $\\alpha = $" + nadler_s30.constraints[0] + "\n $\\sigma = $" + nadler_s30.constraints[1],
                "Our method \n $\\alpha = $" + fiducial_s30.constraints[0] + "\n $\\sigma = $" + fiducial_s30.constraints[1]]

data_s30 = [nadler_s30.clean, fiducial_s30.clean]
test = jsm_mcmc.MulitChain(data_s30, chain_labels, fixed)
test.plot_posteriors(paper=True, filledPlots=True, nContourLevels=3, smoothingKernel=1.5, truths=fid_values, colorsOrder=["oranges", "blues"], paramRanges=[[1.9, 2.3], [0, 1]])

# %%
fiducial_s0 = jsm_mcmc.Chain("../../mcmc/inference_tests/s0/mock_jsm_old/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=30)

# %%
fiducial_s0.blobs["lnL_Msmax"]
# Out:
# array([-2.64584209, -2.50871656, -2.37720214, -2.80030011, -2.14906591,
#        -2.31761422, -2.4730335 , -2.58432263, -2.71293379, -2.72878472,
#        -2.7433043 , -2.75922511, -2.41233451, -2.67609332, -2.52407139,
#        -2.82937393, -2.50871656, -2.64015193, -2.92382687, -2.38321681,
#        -2.56625414, -2.4730335 , -2.58432263, -2.62845899, -2.69017425,
#        -2.74530494, -2.75922511, -2.41233451, -2.58692286, -2.83655294,
#        -2.88298081, -2.79080325, -2.64015193, -3.27806129, -1.98081282,
#        -2.56625414, -2.4730335 , -2.88586783, -2.1971444 , -2.17894556,
#        -2.64537027, -2.54692916, -2.32469567, -2.17776989, -2.71358527,
#        -2.63974161, -2.79080325, -2.79316375, -3.12317761, -1.98081282,
#        -2.45424177, -2.47630557, -2.42471751, -2.28877801, -2.49189117,
#        -2.5623732 , -2.46947116, -2.54692916, -2.17776989, -2.64015193,
#        -3.21307227, -2.77592194, -2.8562552 , -3.12317761, -1.98081282,
# ...

# %%
fiducial_s0.blobs["lnL_N"]
# Out:
# array([-222.74764829, -223.5871881 , -223.58567405, -223.14222795,
#        -223.81735028, -223.19660824, -223.11303734, -223.50056625,
#        -224.11228116, -224.10881534, -222.97449101, -223.03204972,
#        -223.31111124, -222.99216207, -223.82356129, -222.74764829,
#        -223.7081911 , -223.58567405, -223.14222795, -223.81735028,
#        -223.48308785, -222.98630253, -223.50056625, -224.00111576,
#        -223.98673736, -222.97449101, -222.65352684, -223.53710167,
#        -222.66554868, -223.62054091, -222.73123722, -223.95556717,
#        -224.05741359, -222.54912444, -223.08959248, -222.91875393,
#        -222.35194453, -223.50056625, -224.39311549, -223.81811473,
#        -222.4004961 , -222.52294488, -223.33507078, -222.66554868,
#        -223.92538806, -222.89619938, -223.57150237, -223.67564805,
#        -222.54912444, -223.40406313, -222.84175801, -222.82669316,
#        -223.42243404, -224.53282539, -223.7796295 , -222.57461768,
# ...
