# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import warnings; warnings.simplefilter('ignore')
import sys
sys.path.insert(0, '/Users/jsmonzon/Research/SatGen/mcmc/src/')
import jsm_halopull
import jsm_SHMR
import jsm_mcmc
import jsm_stats
import jsm_models

import seaborn as sns

# %%
fixed = [False, True, False, False, True, False]
fid_values = [2.0, 0.2]

s_0_0 = jsm_mcmc.Chain("../../mcmc/inference_tests/our_stats/s0_data/mock_0_0/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)
s_0_0_nadler = jsm_mcmc.Chain("../../mcmc/inference_tests/nadler_stats/s0_data/mock_0_0/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_0_1 = jsm_mcmc.Chain("../../mcmc/inference_tests/our_stats/s0_data/mock_0_1/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)
s_0_1_nadler = jsm_mcmc.Chain("../../mcmc/inference_tests/nadler_stats/s0_data/mock_0_1/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_0_2 = jsm_mcmc.Chain("../../mcmc/inference_tests/our_stats/s0_data/mock_0_2/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)
s_0_2_nadler = jsm_mcmc.Chain("../../mcmc/inference_tests/nadler_stats/s0_data/mock_0_2/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)


s_1_0_nadler = jsm_mcmc.Chain("../../mcmc/inference_tests/nadler_stats/s15_data/mock_1_0/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_1_1 = jsm_mcmc.Chain("../../mcmc/inference_tests/our_stats/s15_data/mock_1_1/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)
s_1_1_nadler = jsm_mcmc.Chain("../../mcmc/inference_tests/nadler_stats/s15_data/mock_1_1/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_1_2 = jsm_mcmc.Chain("../../mcmc/inference_tests/our_stats/s15_data/mock_1_2/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)
s_1_2_nadler = jsm_mcmc.Chain("../../mcmc/inference_tests/nadler_stats/s15_data/mock_1_2/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)


s_2_0_nadler = jsm_mcmc.Chain("../../mcmc/inference_tests/nadler_stats/s30_data/mock_2_0/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_2_1_nadler = jsm_mcmc.Chain("../../mcmc/inference_tests/nadler_stats/s30_data/mock_2_1/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

s_2_2 = jsm_mcmc.Chain("../../mcmc/inference_tests/our_stats/s30_data/mock_2_2/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)
s_2_2_nadler = jsm_mcmc.Chain("../../mcmc/inference_tests/nadler_stats/s30_data/mock_2_2/chain.h5", fixed=fixed, Nstack=500, Nburn=100, Nthin=15)

# %%
plt.style.use('../paper/paper.mplstyle')
double_textwidth = 7.0 #inches
single_textwidth = 3.5 #inches

# %%
# Create a 4x3 subplot grid
fig, axes = plt.subplots(2, 3, sharey="row", figsize=(12, double_textwidth))

# Loop through each subplot and plot KDE of the corresponding parameter
sns.kdeplot(s_0_0.chisq.flatten(), ax=axes[0,0], bw_adjust=2, fill=True, color="green")
sns.kdeplot(s_0_1.chisq.flatten(), ax=axes[0,0], bw_adjust=2, fill=True, color="darkorange")
sns.kdeplot(s_0_2.chisq.flatten(), ax=axes[0,0], bw_adjust=2, fill=True, color="red")
axes[0,0].set_xlabel("$\chi^2_{jsm}$")
axes[0,0].axvline(s_0_0.chisq.flatten().min(), color="green", ls="--")
axes[0,0].set_title("$s_0$ mock")

sns.kdeplot(s_1_1.chisq.flatten(), ax=axes[0,1], bw_adjust=2, fill=True, color="darkorange")
sns.kdeplot(s_1_2.chisq.flatten(), ax=axes[0,1], bw_adjust=2, fill=True, color="red")
axes[0,1].set_xlabel("$\chi^2_{jsm}$")
axes[0,1].axvline(s_1_1.chisq.flatten().min(), color="darkorange", ls="--")
axes[0,1].set_title("$s_{15}$ mock")

sns.kdeplot(s_2_2.chisq.flatten(), ax=axes[0,2], bw_adjust=2, fill=True, color="red")
axes[0,2].set_xlim(640, 670)
axes[0,2].set_xlabel("$\chi^2_{jsm}$")
axes[0,2].axvline(s_2_2.chisq.flatten().min(), color="red", ls="--")
axes[0,2].set_title("$s_{30}$ mock")

sns.kdeplot(s_0_0_nadler.chisq.flatten(), ax=axes[1,0], bw_adjust=2, fill=True, color="green")
sns.kdeplot(s_0_1_nadler.chisq.flatten(), ax=axes[1,0], bw_adjust=2, fill=True, color="darkorange")
sns.kdeplot(s_0_2_nadler.chisq.flatten(), ax=axes[1,0], bw_adjust=2, fill=True, color="red")
axes[1,0].set_xlim(85, 130)
axes[1,0].set_xlabel("$\chi^2_{Nadler}$")
axes[1,0].axvline(s_0_0_nadler.chisq.flatten().min(), color="green", ls="--")

sns.kdeplot(s_1_0_nadler.chisq.flatten(), ax=axes[1,1], bw_adjust=2, fill=True, color="green")
sns.kdeplot(s_1_1_nadler.chisq.flatten(), ax=axes[1,1], bw_adjust=2, fill=True, color="darkorange")
sns.kdeplot(s_1_2_nadler.chisq.flatten(), ax=axes[1,1], bw_adjust=2, fill=True, color="red")
axes[1,1].set_xlim(100, 130)
axes[1,1].set_xlabel("$\chi^2_{Nadler}$")
axes[1,1].axvline(s_1_1_nadler.chisq.flatten().min(), color="darkorange", ls="--")

sns.kdeplot(s_2_0_nadler.chisq.flatten(), ax=axes[1,2], bw_adjust=2, fill=True, color="green")
sns.kdeplot(s_2_1_nadler.chisq.flatten(), ax=axes[1,2], bw_adjust=2, fill=True, color="darkorange")
sns.kdeplot(s_2_2_nadler.chisq.flatten(), ax=axes[1,2], bw_adjust=2, fill=True, color="red")
axes[1,2].set_xlim(100, 140)
axes[1,2].set_xlabel("$\chi^2_{Nadler}$")
axes[1,2].axvline(s_2_2_nadler.chisq.flatten().min(), color="red", ls="--")

plt.tight_layout()
plt.savefig("../../figures/paper/chi_2_cross_sampling.pdf", bbox_inches="tight")
plt.show()
